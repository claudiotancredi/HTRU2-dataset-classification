# %%
import utils
import metrics
import PCA
import balancedSVM
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /opt/anaconda3/envs/bigdatalab_cpu_202101/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.2/matplotlibrc.template
# or from the matplotlib source distribution

# %%
priors = [0.5, 0.9, 0.1]
D, L = utils.load('Train.txt')
ZD, mean, standardDeviation = utils.ZNormalization(D)
C=np.logspace(-5, -2, num=15)
model = balancedSVM.SVM()
PCA7 = PCA.PCA(ZD, L, 7)
PCA6 = PCA.PCA(ZD, L, 6)
print ("Executing linear SVM with class re-balancing")
# Out:
# Executing linear SVM with class re-balancing

# %%
# SINGLE FOLD Z NORMALIZED SVM LINEAR
(DTRSF, LTRSF), (DEVSF, LEVSF) = utils.split_db_singleFold(ZD, L)
minDCF = []
print("Start linear SVM on single fold of z normalized features")
for i in range(len(priors)):
    print("")
    print("Working on application with prior:", priors[i])
    for value in C:
        model.train(DTRSF, LTRSF, option='linear',C=value, piT=0.1) 
        temp = metrics.minimum_detection_costs(model.predictAndGetScores(DEVSF), LEVSF, priors[i], 1, 1)
        minDCF.append(temp)
        print("For C=", value, "the minDCF is", temp)
print("")
print("END")
# Out:
# Start linear SVM on single fold of z normalized features
#
# Working on application with prior: 0.5
# For C= 1e-05 the minDCF is 0.15694586635321478
# For C= 1.6378937069540647e-05 the minDCF is 0.15694586635321478
# For C= 2.6826957952797274e-05 the minDCF is 0.15694586635321478
# For C= 4.393970560760786e-05 the minDCF is 0.15548856785348653
# For C= 7.196856730011514e-05 the minDCF is 0.15209873734501195
# For C= 0.00011787686347935866 the minDCF is 0.15203048572403594
# For C= 0.00019306977288832496 the minDCF is 0.15091191749137375
# For C= 0.00031622776601683794 the minDCF is 0.15080954005990976
# For C= 0.0005179474679231213 the minDCF is 0.14755621279338718
# For C= 0.0008483428982440717 the minDCF is 0.14596241105170693
# For C= 0.0013894954943731374 the minDCF is 0.13921687584524578
# For C= 0.0022758459260747888 the minDCF is 0.13142102402709843
# For C= 0.003727593720314938 the minDCF is 0.12542120097574538
# For C= 0.006105402296585327 the minDCF is 0.12206549627775881
# For C= 0.01 the minDCF is 0.13542006344872912
#
# Working on application with prior: 0.9
# For C= 1e-05 the minDCF is 0.5723783162072322
# For C= 1.6378937069540647e-05 the minDCF is 0.5723783162072322
# For C= 2.6826957952797274e-05 the minDCF is 0.5723783162072322
# For C= 4.393970560760786e-05 the minDCF is 0.5849896990609083
# For C= 7.196856730011514e-05 the minDCF is 0.5919867541298551
# For C= 0.00011787686347935866 the minDCF is 0.6013081560687067
# For C= 0.00019306977288832496 the minDCF is 0.6214423842566262
# For C= 0.00031622776601683794 the minDCF is 0.6304566539010857
# For C= 0.0005179474679231213 the minDCF is 0.631948078211302
# For C= 0.0008483428982440717 the minDCF is 0.637913775452167
# For C= 0.0013894954943731374 the minDCF is 0.6457437530808025
# For C= 0.0022758459260747888 the minDCF is 0.6528280185543296
# For C= 0.003727593720314938 the minDCF is 0.6468408346920463
# For C= 0.006105402296585327 the minDCF is 0.621552345201532
# For C= 0.01 the minDCF is 0.5933897041165839
#
# Working on application with prior: 0.1
# For C= 1e-05 the minDCF is 0.27040154703674213
# For C= 1.6378937069540647e-05 the minDCF is 0.27040154703674213
# For C= 2.6826957952797274e-05 the minDCF is 0.27040154703674213
# For C= 4.393970560760786e-05 the minDCF is 0.27707883062222727
# For C= 7.196856730011514e-05 the minDCF is 0.28379024001820047
# For C= 0.00011787686347935866 the minDCF is 0.29406210897508817
# For C= 0.00019306977288832496 the minDCF is 0.29738368786258673
# For C= 0.00031622776601683794 the minDCF is 0.29738368786258673
# For C= 0.0005179474679231213 the minDCF is 0.287521328631555
# For C= 0.0008483428982440717 the minDCF is 0.287350699579115
# For C= 0.0013894954943731374 the minDCF is 0.2736890001137527
# For C= 0.0022758459260747888 the minDCF is 0.2599590490274144
# For C= 0.003727593720314938 the minDCF is 0.2465703560459561
# For C= 0.006105402296585327 the minDCF is 0.2467068592879081
# For C= 0.01 the minDCF is 0.25002843817540665
#
# END

# %%
utils.plotDCF(C, minDCF, "C")

# %%
# SINGLE FOLD Z NORMALIZED SVM LINEAR WITH PCA = 7
(DTRSF, LTRSF), (DEVSF, LEVSF) = utils.split_db_singleFold(PCA7, L)
minDCF7 = []
print("Start linear SVM on single fold of z normalized features with PCA = 7")
for i in range(len(priors)):
    print("")
    print("Working on application with prior:", priors[i])
    for value in C:
        model.train(DTRSF, LTRSF, option='linear',C=value, piT=0.1) 
        temp = metrics.minimum_detection_costs(model.predictAndGetScores(DEVSF), LEVSF, priors[i], 1, 1)
        minDCF7.append(temp)
        print("For C=", value, "the minDCF is", temp)
print("")
print("END")
# Out:
# Start linear SVM on single fold of z normalized features with PCA = 7
#
# Working on application with prior: 0.5
# For C= 1e-05 the minDCF is 0.15694586635321478
# For C= 1.6378937069540647e-05 the minDCF is 0.15694586635321478
# For C= 2.6826957952797274e-05 the minDCF is 0.15694586635321478
# For C= 4.393970560760786e-05 the minDCF is 0.15548856785348653
# For C= 7.196856730011514e-05 the minDCF is 0.15209873734501195
# For C= 0.00011787686347935866 the minDCF is 0.15203048572403594
# For C= 0.00019306977288832496 the minDCF is 0.15091191749137375
# For C= 0.00031622776601683794 the minDCF is 0.15080954005990976
# For C= 0.0005179474679231213 the minDCF is 0.14755621279338718
# For C= 0.0008483428982440717 the minDCF is 0.14596241105170693
# For C= 0.0013894954943731374 the minDCF is 0.13921687584524578
# For C= 0.0022758459260747888 the minDCF is 0.13142102402709843
# For C= 0.003727593720314938 the minDCF is 0.12542120097574538
# For C= 0.006105402296585327 the minDCF is 0.12240422654482488
# For C= 0.01 the minDCF is 0.13653863168139133
#
# Working on application with prior: 0.9
# For C= 1e-05 the minDCF is 0.5723783162072322
# For C= 1.6378937069540647e-05 the minDCF is 0.5723783162072322
# For C= 2.6826957952797274e-05 the minDCF is 0.5723783162072322
# For C= 4.393970560760786e-05 the minDCF is 0.5849896990609083
# For C= 7.196856730011514e-05 the minDCF is 0.5919867541298551
# For C= 0.00011787686347935866 the minDCF is 0.6013081560687067
# For C= 0.00019306977288832496 the minDCF is 0.6214423842566262
# For C= 0.00031622776601683794 the minDCF is 0.6304566539010857
# For C= 0.0005179474679231213 the minDCF is 0.631948078211302
# For C= 0.0008483428982440717 the minDCF is 0.637913775452167
# For C= 0.0013894954943731374 the minDCF is 0.6457437530808025
# For C= 0.0022758459260747888 the minDCF is 0.6528280185543296
# For C= 0.003727593720314938 the minDCF is 0.6468408346920463
# For C= 0.006105402296585327 the minDCF is 0.6219252012790861
# For C= 0.01 the minDCF is 0.5963953032773418
#
# Working on application with prior: 0.1
# For C= 1e-05 the minDCF is 0.27040154703674213
# For C= 1.6378937069540647e-05 the minDCF is 0.27040154703674213
# For C= 2.6826957952797274e-05 the minDCF is 0.27040154703674213
# For C= 4.393970560760786e-05 the minDCF is 0.27707883062222727
# For C= 7.196856730011514e-05 the minDCF is 0.28379024001820047
# For C= 0.00011787686347935866 the minDCF is 0.29406210897508817
# For C= 0.00019306977288832496 the minDCF is 0.29738368786258673
# For C= 0.00031622776601683794 the minDCF is 0.29738368786258673
# For C= 0.0005179474679231213 the minDCF is 0.287521328631555
# For C= 0.0008483428982440717 the minDCF is 0.287350699579115
# For C= 0.0013894954943731374 the minDCF is 0.2736890001137527
# For C= 0.0022758459260747888 the minDCF is 0.2599590490274144
# For C= 0.003727593720314938 the minDCF is 0.2465703560459561
# For C= 0.006105402296585327 the minDCF is 0.2467068592879081
# For C= 0.01 the minDCF is 0.2567057217608918
#
# END

# %%
utils.plotDCF(C, minDCF7, "C")

# %%
# SINGLE FOLD Z NORMALIZED SVM LINEAR WITH PCA = 6
(DTRSF, LTRSF), (DEVSF, LEVSF) = utils.split_db_singleFold(PCA6, L)
minDCF6 = []
print("Start linear SVM on single fold of z normalized features with PCA = 6")
for i in range(len(priors)):
    print("")
    print("Working on application with prior:", priors[i])
    for value in C:
        model.train(DTRSF, LTRSF, option='linear',C=value, piT=0.1) 
        temp = metrics.minimum_detection_costs(model.predictAndGetScores(DEVSF), LEVSF, priors[i], 1, 1)
        minDCF6.append(temp)
        print("For C=", value, "the minDCF is", temp)
print("")
print("END")
# Out:
# Start linear SVM on single fold of z normalized features with PCA = 6
#
# Working on application with prior: 0.5
# For C= 1e-05 the minDCF is 0.15694586635321478
# For C= 1.6378937069540647e-05 the minDCF is 0.15694586635321478
# For C= 2.6826957952797274e-05 the minDCF is 0.15694586635321478
# For C= 4.393970560760786e-05 the minDCF is 0.15582729812055257
# For C= 7.196856730011514e-05 the minDCF is 0.15321730557767413
# For C= 0.00011787686347935866 the minDCF is 0.15314905395669814
# For C= 0.00019306977288832496 the minDCF is 0.15091191749137375
# For C= 0.00031622776601683794 the minDCF is 0.15128477356892783
# For C= 0.0005179474679231213 the minDCF is 0.14857240359458537
# For C= 0.0008483428982440717 the minDCF is 0.1474538353619232
# For C= 0.0013894954943731374 the minDCF is 0.13928512746622176
# For C= 0.0022758459260747888 the minDCF is 0.13179388010465248
# For C= 0.003727593720314938 the minDCF is 0.12613278732036554
# For C= 0.006105402296585327 the minDCF is 0.12314993869993301
# For C= 0.01 the minDCF is 0.1428771849998104
#
# Working on application with prior: 0.9
# For C= 1e-05 the minDCF is 0.5716326040521241
# For C= 1.6378937069540647e-05 the minDCF is 0.5716326040521241
# For C= 2.6826957952797274e-05 the minDCF is 0.5716326040521241
# For C= 4.393970560760786e-05 the minDCF is 0.582752562595584
# For C= 7.196856730011514e-05 the minDCF is 0.591241041974747
# For C= 0.00011787686347935866 the minDCF is 0.6054095729218014
# For C= 0.00019306977288832496 the minDCF is 0.6244252328770588
# For C= 0.00031622776601683794 the minDCF is 0.631575222133748
# For C= 0.0005179474679231213 the minDCF is 0.6341852146766265
# For C= 0.0008483428982440717 the minDCF is 0.6427609044603699
# For C= 0.0013894954943731374 the minDCF is 0.6498451699338971
# For C= 0.0022758459260747888 the minDCF is 0.6541222715150597
# For C= 0.003727593720314938 the minDCF is 0.650262263173195
# For C= 0.006105402296585327 the minDCF is 0.6230437695117482
# For C= 0.01 the minDCF is 0.6007811018845032
#
# Working on application with prior: 0.1
# For C= 1e-05 the minDCF is 0.27040154703674213
# For C= 1.6378937069540647e-05 the minDCF is 0.27040154703674213
# For C= 2.6826957952797274e-05 the minDCF is 0.27040154703674213
# For C= 4.393970560760786e-05 the minDCF is 0.27707883062222727
# For C= 7.196856730011514e-05 the minDCF is 0.28379024001820047
# For C= 0.00011787686347935866 the minDCF is 0.2973495620520987
# For C= 0.00019306977288832496 the minDCF is 0.29738368786258673
# For C= 0.00031622776601683794 the minDCF is 0.3007393925605733
# For C= 0.0005179474679231213 the minDCF is 0.29084290751905356
# For C= 0.0008483428982440717 the minDCF is 0.29087703332954157
# For C= 0.0013894954943731374 the minDCF is 0.2738596291661927
# For C= 0.0022758459260747888 the minDCF is 0.2601296780798544
# For C= 0.003727593720314938 the minDCF is 0.2499601865544307
# For C= 0.006105402296585327 the minDCF is 0.25341826868388123
# For C= 0.01 the minDCF is 0.27348424525082465
#
# END

# %%
utils.plotDCF(C, minDCF6, "C")

# %%
minDCF3fold = []
print("Start linear SVM with 3-fold on z normalized features")

for i in range(len(priors)):
    print("")
    print("Working on application with prior:", priors[i])
    for value in C:
        temp = utils.KfoldSVM(ZD, L, model, option='linear', C=value, prior=priors[i], piT=0.1)
        minDCF3fold.append(temp)
        print("For C=", value, "the minDCF is", temp)
print("")
print("END")
# Out:
# Start linear SVM with 3-fold on z normalized features
#
# Working on application with prior: 0.5
# For C= 1e-05 the minDCF is 0.17905264348774844
# For C= 1.6378937069540647e-05 the minDCF is 0.17905264348774844
# For C= 2.6826957952797274e-05 the minDCF is 0.17942269406132683
# For C= 4.393970560760786e-05 the minDCF is 0.17912956833292593
# For C= 7.196856730011514e-05 the minDCF is 0.1786980680295085
# For C= 0.00011787686347935866 the minDCF is 0.17880594310536285
# For C= 0.00019306977288832496 the minDCF is 0.17863661829966945
# For C= 0.00031622776601683794 the minDCF is 0.179237894140295
# For C= 0.0005179474679231213 the minDCF is 0.17763479238630336
# For C= 0.0008483428982440717 the minDCF is 0.17760384215562647
# For C= 0.0013894954943731374 the minDCF is 0.17661658989456938
# For C= 0.0022758459260747888 the minDCF is 0.1700790297613512
# For C= 0.003727593720314938 the minDCF is 0.1622924926008666
# For C= 0.006105402296585327 the minDCF is 0.1543061311355264
# For C= 0.01 the minDCF is 0.15640263365428922
#
# Working on application with prior: 0.9
# For C= 1e-05 the minDCF is 0.6239727265365325
# For C= 1.6378937069540647e-05 the minDCF is 0.6239727265365325
# For C= 2.6826957952797274e-05 the minDCF is 0.6242194269189181
# For C= 4.393970560760786e-05 the minDCF is 0.627780656616656
# For C= 7.196856730011514e-05 the minDCF is 0.64295273013337
# For C= 0.00011787686347935866 the minDCF is 0.6524625641184361
# For C= 0.00019306977288832496 the minDCF is 0.6581207470664516
# For C= 0.00031622776601683794 the minDCF is 0.6735235951186979
# For C= 0.0005179474679231213 the minDCF is 0.682528159075772
# For C= 0.0008483428982440717 the minDCF is 0.6875258701108965
# For C= 0.0013894954943731374 the minDCF is 0.6803715590217142
# For C= 0.0022758459260747888 the minDCF is 0.6670497383728924
# For C= 0.003727593720314938 the minDCF is 0.6739414232328357
# For C= 0.006105402296585327 the minDCF is 0.6634885086751545
# For C= 0.01 the minDCF is 0.6431994305157556
#
# Working on application with prior: 0.1
# For C= 1e-05 the minDCF is 0.3192035514037507
# For C= 1.6378937069540647e-05 the minDCF is 0.3192035514037507
# For C= 2.6826957952797274e-05 the minDCF is 0.3192035514037507
# For C= 4.393970560760786e-05 the minDCF is 0.3246150339693806
# For C= 7.196856730011514e-05 the minDCF is 0.3279454891315861
# For C= 0.00011787686347935866 the minDCF is 0.33428277422843405
# For C= 0.00019306977288832496 the minDCF is 0.3408044085147991
# For C= 0.00031622776601683794 the minDCF is 0.3429168368804151
# For C= 0.0005179474679231213 the minDCF is 0.33536152498697763
# For C= 0.0008483428982440717 the minDCF is 0.33227822093867243
# For C= 0.0013894954943731374 the minDCF is 0.3222731832627763
# For C= 0.0022758459260747888 the minDCF is 0.3063760329827293
# For C= 0.003727593720314938 the minDCF is 0.28312564877167395
# For C= 0.006105402296585327 the minDCF is 0.2731342832850575
# For C= 0.01 the minDCF is 0.2848516499853437
#
# END

# %%
utils.plotDCF(C, minDCF3fold, "C")

# %%
minDCF3fold7 = []
print("Start linear SVM with 3-fold on z normalized features with PCA = 7")
for i in range(len(priors)):
    print("")
    print("Working on application with prior:", priors[i])
    for value in C:
        temp = utils.KfoldSVM(PCA7, L, model, option='linear', C=value, prior=priors[i], piT=0.1)
        minDCF3fold7.append(temp)
        print("For C=", value, "the minDCF is", temp)
print("")
print("END")
# Out:
# Start linear SVM with 3-fold on z normalized features with PCA = 7
#
# Working on application with prior: 0.5
# For C= 1e-05 the minDCF is 0.17905264348774844
# For C= 1.6378937069540647e-05 the minDCF is 0.17905264348774844
# For C= 2.6826957952797274e-05 the minDCF is 0.17942269406132683
# For C= 4.393970560760786e-05 the minDCF is 0.17912956833292593
# For C= 7.196856730011514e-05 the minDCF is 0.1786980680295085
# For C= 0.00011787686347935866 the minDCF is 0.17892929329655566
# For C= 0.00019306977288832496 the minDCF is 0.17863661829966945
# For C= 0.00031622776601683794 the minDCF is 0.1791145439491022
# For C= 0.0005179474679231213 the minDCF is 0.17763479238630336
# For C= 0.0008483428982440717 the minDCF is 0.17760339142411175
# For C= 0.0013894954943731374 the minDCF is 0.1764932397033766
# For C= 0.0022758459260747888 the minDCF is 0.16983232937896559
# For C= 0.003727593720314938 the minDCF is 0.16204579221848098
# For C= 0.006105402296585327 the minDCF is 0.1541827809443336
# For C= 0.01 the minDCF is 0.15701938461025322
#
# Working on application with prior: 0.9
# For C= 1e-05 the minDCF is 0.6239727265365325
# For C= 1.6378937069540647e-05 the minDCF is 0.6239727265365325
# For C= 2.6826957952797274e-05 the minDCF is 0.6242194269189181
# For C= 4.393970560760786e-05 the minDCF is 0.627780656616656
# For C= 7.196856730011514e-05 the minDCF is 0.6434461308981413
# For C= 0.00011787686347935866 the minDCF is 0.6523392139272433
# For C= 0.00019306977288832496 the minDCF is 0.657874046684066
# For C= 0.00031622776601683794 the minDCF is 0.6731535445451196
# For C= 0.0005179474679231213 the minDCF is 0.6820347583110008
# For C= 0.0008483428982440717 the minDCF is 0.6876492203020894
# For C= 0.0013894954943731374 the minDCF is 0.680001508448136
# For C= 0.0022758459260747888 the minDCF is 0.6669263881816996
# For C= 0.003727593720314938 the minDCF is 0.6735713726592574
# For C= 0.006105402296585327 the minDCF is 0.6657088121166248
# For C= 0.01 the minDCF is 0.6464265179172539
#
# Working on application with prior: 0.1
# For C= 1e-05 the minDCF is 0.3192035514037507
# For C= 1.6378937069540647e-05 the minDCF is 0.3192035514037507
# For C= 2.6826957952797274e-05 the minDCF is 0.3192035514037507
# For C= 4.393970560760786e-05 the minDCF is 0.3246150339693806
# For C= 7.196856730011514e-05 the minDCF is 0.3279454891315861
# For C= 0.00011787686347935866 the minDCF is 0.33428277422843405
# For C= 0.00019306977288832496 the minDCF is 0.3408044085147991
# For C= 0.00031622776601683794 the minDCF is 0.3429168368804151
# For C= 0.0005179474679231213 the minDCF is 0.33536152498697763
# For C= 0.0008483428982440717 the minDCF is 0.33227822093867243
# For C= 0.0013894954943731374 the minDCF is 0.3222731832627763
# For C= 0.0022758459260747888 the minDCF is 0.30648390805858367
# For C= 0.003727593720314938 the minDCF is 0.2820154970509388
# For C= 0.006105402296585327 the minDCF is 0.27424443500579265
# For C= 0.01 the minDCF is 0.2828470966955821
#
# END

# %%
utils.plotDCF(C, minDCF3fold7, "C")

# %%
minDCF3fold6 = []
print("Start linear SVM with 3-fold on z normalized features with PCA = 6")
for i in range(len(priors)):
    print("")
    print("Working on application with prior:", priors[i])
    for value in C:
        temp = utils.KfoldSVM(PCA6, L, model, option='linear', C=value, prior=priors[i], piT=0.1)
        minDCF3fold6.append(temp)
        print("For C=", value, "the minDCF is", temp)
print("")
print("END")
# Out:
# Start linear SVM with 3-fold on z normalized features with PCA = 6
#
# Working on application with prior: 0.5
# For C= 1e-05 the minDCF is 0.17942269406132683
# For C= 1.6378937069540647e-05 the minDCF is 0.17942269406132683
# For C= 2.6826957952797274e-05 the minDCF is 0.17991609482609802
# For C= 4.393970560760786e-05 the minDCF is 0.1792529185241187
# For C= 7.196856730011514e-05 the minDCF is 0.1794072189459884
# For C= 0.00011787686347935866 the minDCF is 0.17905264348774844
# For C= 0.00019306977288832496 the minDCF is 0.17913001906444065
# For C= 0.00031622776601683794 the minDCF is 0.18022469566983737
# For C= 0.0005179474679231213 the minDCF is 0.17900711960476257
# For C= 0.0008483428982440717 the minDCF is 0.17822059311159044
# For C= 0.0013894954943731374 the minDCF is 0.17706311458181054
# For C= 0.0022758459260747888 the minDCF is 0.17114275613607105
# For C= 0.003727593720314938 the minDCF is 0.1632638190150705
# For C= 0.006105402296585327 the minDCF is 0.15677313495938233
# For C= 0.01 the minDCF is 0.1610439663051149
#
# Working on application with prior: 0.9
# For C= 1e-05 the minDCF is 0.6229859250069901
# For C= 1.6378937069540647e-05 the minDCF is 0.6229859250069901
# For C= 2.6826957952797274e-05 the minDCF is 0.6232326253893757
# For C= 4.393970560760786e-05 the minDCF is 0.6272872558518848
# For C= 7.196856730011514e-05 the minDCF is 0.6394989247799716
# For C= 0.00011787686347935866 the minDCF is 0.6519891457841505
# For C= 0.00019306977288832496 the minDCF is 0.6604644006991148
# For C= 0.00031622776601683794 the minDCF is 0.6783342525752168
# For C= 0.0005179474679231213 the minDCF is 0.686228664811556
# For C= 0.0008483428982440717 the minDCF is 0.6868772674612262
# For C= 0.0013894954943731374 the minDCF is 0.6814498590487432
# For C= 0.0022758459260747888 the minDCF is 0.6692700418143627
# For C= 0.003727593720314938 the minDCF is 0.6778886293510051
# For C= 0.006105402296585327 the minDCF is 0.6677739136731959
# For C= 0.01 the minDCF is 0.6498484715769458
#
# Working on application with prior: 0.1
# For C= 1e-05 the minDCF is 0.3192035514037507
# For C= 1.6378937069540647e-05 the minDCF is 0.3192035514037507
# For C= 2.6826957952797274e-05 the minDCF is 0.3192035514037507
# For C= 4.393970560760786e-05 the minDCF is 0.3254015604625527
# For C= 7.196856730011514e-05 the minDCF is 0.3300579174972021
# For C= 0.00011787686347935866 the minDCF is 0.33625592655600406
# For C= 0.00019306977288832496 the minDCF is 0.34205383627358016
# For C= 0.00031622776601683794 the minDCF is 0.34549216651164005
# For C= 0.0005179474679231213 the minDCF is 0.3363638016318585
# For C= 0.0008483428982440717 the minDCF is 0.3330647474318445
# For C= 0.0013894954943731374 the minDCF is 0.3229969078315652
# For C= 0.0022758459260747888 the minDCF is 0.3063760329827293
# For C= 0.003727593720314938 the minDCF is 0.28778200580632335
# For C= 0.006105402296585327 the minDCF is 0.27779064031970685
# For C= 0.01 the minDCF is 0.290371007626828
#
# END

# %%
utils.plotDCF(C, minDCF3fold6, "C")
