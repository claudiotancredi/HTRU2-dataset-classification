# %%
import utils
import metrics
import PCA
import balancedSVM
import matplotlib.pyplot as plt
import numpy as np

# %%
priors = [0.5, 0.9, 0.1]
D, L = utils.load('Train.txt')
ZD, mean, standardDeviation = utils.ZNormalization(D)
C=np.logspace(-4, -2.522878, num=30)
model = balancedSVM.SVM()
PCA7 = PCA.PCA(ZD, L, 7)
PCA6 = PCA.PCA(ZD, L, 6)
print ("Executing linear SVM with class re-balancing")
# Out:
# Executing linear SVM with class re-balancing

# %%
# SINGLE FOLD Z NORMALIZED SVM LINEAR
(DTRSF, LTRSF), (DEVSF, LEVSF) = utils.split_db_singleFold(ZD, L)
minDCF = []
print("Start linear SVM on single fold of z normalized features")
for i in range(len(priors)):
    print("")
    print("Working on application with prior:", priors[i])
    for value in C:
        model.train(DTRSF, LTRSF, option='linear',C=value) 
        temp = metrics.minimum_detection_costs(model.predictAndGetScores(DEVSF), LEVSF, priors[i], 1, 1)
        minDCF.append(temp)
        print("For C=", value, "the minDCF is", temp)
print("")
print("END")
# Out:
# Start linear SVM on single fold of z normalized features
#
# Working on application with prior: 0.5
# For C= 0.0001 the minDCF is 0.14596241105170693
# For C= 0.00011244372941080375 the minDCF is 0.1452166988965988
# For C= 0.00012643592283810052 the minDCF is 0.1441322564744246
# For C= 0.00014216926695412638 the minDCF is 0.1400308396213299
# For C= 0.00015986042583922126 the minDCF is 0.1369797393799214
# For C= 0.00017975302466561254 the minDCF is 0.134742602914597
# For C= 0.0002021210046627367 the minDCF is 0.13511545899215105
# For C= 0.0002272723955653657 the minDCF is 0.13325117860438074
# For C= 0.00025555355749497135 the minDCF is 0.13142102402709843
# For C= 0.00028735395068932865 the minDCF is 0.1306753118719903
# For C= 0.00032311149876436315 the minDCF is 0.12992959971688217
# For C= 0.000363318619365793 the minDCF is 0.1273196071740037
# For C= 0.0004085290052587403 the minDCF is 0.12542120097574538
# For C= 0.00045936524923778616 the minDCF is 0.12094692804509663
# For C= 0.0005165274178602006 the minDCF is 0.1202012158899885
# For C= 0.0005808026920713355 the minDCF is 0.12091280223460862
# For C= 0.0006530762074833568 the minDCF is 0.12206549627775881
# For C= 0.0007343432435889251 the minDCF is 0.12501421908770333
# For C= 0.0008257229297676503 the minDCF is 0.12687849947547364
# For C= 0.0009284736568308978 the minDCF is 0.1264373917769436
# For C= 0.0010440104063375304 the minDCF is 0.1316573768627005
# For C= 0.0011739242363228055 the minDCF is 0.13958973192279983
# For C= 0.0013200041917786596 the minDCF is 0.14016481502546796
# For C= 0.001484261941614863 the minDCF is 0.1458600336202429
# For C= 0.0016689594813769587 the minDCF is 0.14762193657654926
# For C= 0.001876640283215461 the minDCF is 0.15257144301621606
# For C= 0.002110164322072934 the minDCF is 0.15474032786056446
# For C= 0.0023727474604350114 the minDCF is 0.15443825124180033
# For C= 0.002668005734013265 the minDCF is 0.14464161579393064
# For C= 0.0030000051482186037 the minDCF is 0.12176089182118076
#
# Working on application with prior: 0.9
# For C= 0.0001 the minDCF is 0.6427609044603699
# For C= 0.00011244372941080375 the minDCF is 0.6453708970032483
# For C= 0.00012643592283810052 the minDCF is 0.6532008746318838
# For C= 0.00014216926695412638 the minDCF is 0.6405237679950455
# For C= 0.00015986042583922126 the minDCF is 0.6479808895461269
# For C= 0.00017975302466561254 the minDCF is 0.6580480036400865
# For C= 0.0002021210046627367 the minDCF is 0.6561837232523161
# For C= 0.0002272723955653657 the minDCF is 0.6535737307094378
# For C= 0.00025555355749497135 the minDCF is 0.6543194428645459
# For C= 0.00028735395068932865 the minDCF is 0.6532008746318838
# For C= 0.00032311149876436315 the minDCF is 0.6518851350497354
# For C= 0.000363318619365793 the minDCF is 0.6490779711573706
# For C= 0.0004085290052587403 the minDCF is 0.6475865468471543
# For C= 0.00045936524923778616 the minDCF is 0.6427394178389516
# For C= 0.0005165274178602006 the minDCF is 0.6420594294670056
# For C= 0.0005808026920713355 the minDCF is 0.6353480200710324
# For C= 0.0006530762074833568 the minDCF is 0.6222980573566401
# For C= 0.0007343432435889251 the minDCF is 0.6242053109872471
# For C= 0.0008257229297676503 the minDCF is 0.6111553482728549
# For C= 0.0009284736568308978 the minDCF is 0.6108052427356262
# For C= 0.0010440104063375304 the minDCF is 0.5968553697594763
# For C= 0.0011739242363228055 the minDCF is 0.5684968212439491
# For C= 0.0013200041917786596 the minDCF is 0.5686282688102733
# For C= 0.001484261941614863 the minDCF is 0.537746938156448
# For C= 0.0016689594813769587 the minDCF is 0.5396769423273803
# For C= 0.001876640283215461 the minDCF is 0.5169327215965824
# For C= 0.002110164322072934 the minDCF is 0.52588126745788
# For C= 0.0023727474604350114 the minDCF is 0.5440854914748671
# For C= 0.002668005734013265 the minDCF is 0.5242583955813396
# For C= 0.0030000051482186037 the minDCF is 0.49462708072650063
#
# Working on application with prior: 0.1
# For C= 0.0001 the minDCF is 0.287350699579115
# For C= 0.00011244372941080375 the minDCF is 0.2839949948811284
# For C= 0.00012643592283810052 the minDCF is 0.2839949948811284
# For C= 0.00014216926695412638 the minDCF is 0.2736890001137527
# For C= 0.00015986042583922126 the minDCF is 0.2703332954157661
# For C= 0.00017975302466561254 the minDCF is 0.2703332954157661
# For C= 0.0002021210046627367 the minDCF is 0.2702991696052781
# For C= 0.0002272723955653657 the minDCF is 0.2601296780798544
# For C= 0.00025555355749497135 the minDCF is 0.2599590490274144
# For C= 0.00028735395068932865 the minDCF is 0.2565692185189398
# For C= 0.00032311149876436315 the minDCF is 0.24663860766693207
# For C= 0.000363318619365793 the minDCF is 0.24324877715845752
# For C= 0.0004085290052587403 the minDCF is 0.2465703560459561
# For C= 0.00045936524923778616 the minDCF is 0.24324877715845752
# For C= 0.0005165274178602006 the minDCF is 0.24328290296894547
# For C= 0.0005808026920713355 the minDCF is 0.2399271982709589
# For C= 0.0006530762074833568 the minDCF is 0.2467068592879081
# For C= 0.0007343432435889251 the minDCF is 0.24331702877943348
# For C= 0.0008257229297676503 the minDCF is 0.2467068592879081
# For C= 0.0009284736568308978 the minDCF is 0.2467409850983961
# For C= 0.0010440104063375304 the minDCF is 0.2533841428733932
# For C= 0.0011739242363228055 the minDCF is 0.26351950858832895
# For C= 0.0013200041917786596 the minDCF is 0.27019679217381415
# For C= 0.001484261941614863 the minDCF is 0.2939597315436242
# For C= 0.0016689594813769587 the minDCF is 0.29074053008758954
# For C= 0.001876640283215461 the minDCF is 0.29741781367307474
# For C= 0.002110164322072934 the minDCF is 0.29080878170856556
# For C= 0.0023727474604350114 the minDCF is 0.2840291206916164
# For C= 0.002668005734013265 the minDCF is 0.2771129564327153
# For C= 0.0030000051482186037 the minDCF is 0.23633261289955637
#
# END

# %%
utils.plotDCF(C, minDCF, "C")

# %%
# SINGLE FOLD Z NORMALIZED SVM LINEAR WITH PCA = 7
(DTRSF, LTRSF), (DEVSF, LEVSF) = utils.split_db_singleFold(PCA7, L)
minDCF7 = []
print("Start linear SVM on single fold of z normalized features with PCA = 7")
for i in range(len(priors)):
    print("")
    print("Working on application with prior:", priors[i])
    for value in C:
        model.train(DTRSF, LTRSF, option='linear',C=value) 
        temp = metrics.minimum_detection_costs(model.predictAndGetScores(DEVSF), LEVSF, priors[i], 1, 1)
        minDCF7.append(temp)
        print("For C=", value, "the minDCF is", temp)
print("")
print("END")
# Out:
# Start linear SVM on single fold of z normalized features with PCA = 7
#
# Working on application with prior: 0.5
# For C= 0.0001 the minDCF is 0.14596241105170693
# For C= 0.00011244372941080375 the minDCF is 0.1452166988965988
# For C= 0.00012643592283810052 the minDCF is 0.1441322564744246
# For C= 0.00014216926695412638 the minDCF is 0.1400308396213299
# For C= 0.00015986042583922126 the minDCF is 0.13623402722481326
# For C= 0.00017975302466561254 the minDCF is 0.134742602914597
# For C= 0.0002021210046627367 the minDCF is 0.13511545899215105
# For C= 0.0002272723955653657 the minDCF is 0.13325117860438074
# For C= 0.00025555355749497135 the minDCF is 0.13135277240612242
# For C= 0.00028735395068932865 the minDCF is 0.1306753118719903
# For C= 0.00032311149876436315 the minDCF is 0.12992959971688217
# For C= 0.000363318619365793 the minDCF is 0.1273196071740037
# For C= 0.0004085290052587403 the minDCF is 0.12542120097574538
# For C= 0.00045936524923778616 the minDCF is 0.12094692804509663
# For C= 0.0005165274178602006 the minDCF is 0.11982835981243443
# For C= 0.0005808026920713355 the minDCF is 0.1201670900795005
# For C= 0.0006530762074833568 the minDCF is 0.12091280223460862
# For C= 0.0007343432435889251 the minDCF is 0.12389565085504115
# For C= 0.0008257229297676503 the minDCF is 0.12792881608715986
# For C= 0.0009284736568308978 the minDCF is 0.12755596000960578
# For C= 0.0010440104063375304 the minDCF is 0.13169150267318847
# For C= 0.0011739242363228055 the minDCF is 0.13958973192279983
# For C= 0.0013200041917786596 the minDCF is 0.14274068175785842
# For C= 0.001484261941614863 the minDCF is 0.14392750161149662
# For C= 0.0016689594813769587 the minDCF is 0.146130512266333
# For C= 0.001876640283215461 the minDCF is 0.1525373172057281
# For C= 0.002110164322072934 the minDCF is 0.14955446858529559
# For C= 0.0023727474604350114 the minDCF is 0.15135302518990382
# For C= 0.002668005734013265 the minDCF is 0.13630227884578927
# For C= 0.0030000051482186037 the minDCF is 0.12359104639846308
#
# Working on application with prior: 0.9
# For C= 0.0001 the minDCF is 0.6427609044603699
# For C= 0.00011244372941080375 the minDCF is 0.6453708970032483
# For C= 0.00012643592283810052 the minDCF is 0.6532008746318838
# For C= 0.00014216926695412638 the minDCF is 0.6405237679950455
# For C= 0.00015986042583922126 the minDCF is 0.6453708970032483
# For C= 0.00017975302466561254 the minDCF is 0.6580480036400865
# For C= 0.0002021210046627367 the minDCF is 0.6561837232523161
# For C= 0.0002272723955653657 the minDCF is 0.6535737307094378
# For C= 0.00025555355749497135 the minDCF is 0.6543194428645459
# For C= 0.00028735395068932865 the minDCF is 0.6532008746318838
# For C= 0.00032311149876436315 the minDCF is 0.6526308472048435
# For C= 0.000363318619365793 the minDCF is 0.6487051150798167
# For C= 0.0004085290052587403 the minDCF is 0.6479594029247085
# For C= 0.00045936524923778616 the minDCF is 0.6434851299940597
# For C= 0.0005165274178602006 the minDCF is 0.6420594294670056
# For C= 0.0005808026920713355 the minDCF is 0.6360937322261405
# For C= 0.0006530762074833568 the minDCF is 0.6230437695117482
# For C= 0.0007343432435889251 the minDCF is 0.6282637545975052
# For C= 0.0008257229297676503 the minDCF is 0.6137653408157333
# For C= 0.0009284736568308978 the minDCF is 0.6178895082091534
# For C= 0.0010440104063375304 the minDCF is 0.5964825136819223
# For C= 0.0011739242363228055 the minDCF is 0.568123965166395
# For C= 0.0013200041917786596 the minDCF is 0.5563240182509892
# For C= 0.001484261941614863 the minDCF is 0.5403569306993263
# For C= 0.0016689594813769587 the minDCF is 0.5571354541892592
# For C= 0.001876640283215461 the minDCF is 0.519542714139461
# For C= 0.002110164322072934 the minDCF is 0.5154412972863661
# For C= 0.0023727474604350114 the minDCF is 0.5598768942984618
# For C= 0.002668005734013265 the minDCF is 0.5102870359837713
# For C= 0.0030000051482186037 the minDCF is 0.4883542511912436
#
# Working on application with prior: 0.1
# For C= 0.0001 the minDCF is 0.287350699579115
# For C= 0.00011244372941080375 the minDCF is 0.2839949948811284
# For C= 0.00012643592283810052 the minDCF is 0.2839949948811284
# For C= 0.00014216926695412638 the minDCF is 0.2736890001137527
# For C= 0.00015986042583922126 the minDCF is 0.2703332954157661
# For C= 0.00017975302466561254 the minDCF is 0.2703332954157661
# For C= 0.0002021210046627367 the minDCF is 0.2702991696052781
# For C= 0.0002272723955653657 the minDCF is 0.2601296780798544
# For C= 0.00025555355749497135 the minDCF is 0.2599590490274144
# For C= 0.00028735395068932865 the minDCF is 0.2565350927084518
# For C= 0.00032311149876436315 the minDCF is 0.24663860766693207
# For C= 0.000363318619365793 the minDCF is 0.2465703560459561
# For C= 0.0004085290052587403 the minDCF is 0.2465703560459561
# For C= 0.00045936524923778616 the minDCF is 0.24324877715845752
# For C= 0.0005165274178602006 the minDCF is 0.24328290296894547
# For C= 0.0005808026920713355 the minDCF is 0.2399271982709589
# For C= 0.0006530762074833568 the minDCF is 0.24667273347742008
# For C= 0.0007343432435889251 the minDCF is 0.24331702877943348
# For C= 0.0008257229297676503 the minDCF is 0.2467068592879081
# For C= 0.0009284736568308978 the minDCF is 0.2467409850983961
# For C= 0.0010440104063375304 the minDCF is 0.2533158912524172
# For C= 0.0011739242363228055 the minDCF is 0.26358776020930497
# For C= 0.0013200041917786596 the minDCF is 0.27019679217381415
# For C= 0.001484261941614863 the minDCF is 0.29687180070526675
# For C= 0.0016689594813769587 the minDCF is 0.29409623478557617
# For C= 0.001876640283215461 the minDCF is 0.29399385735411215
# For C= 0.002110164322072934 the minDCF is 0.2941303605960642
# For C= 0.0023727474604350114 the minDCF is 0.2941303605960642
# For C= 0.002668005734013265 the minDCF is 0.2841314981230804
# For C= 0.0030000051482186037 the minDCF is 0.2603685587532704
#
# END

# %%
utils.plotDCF(C, minDCF7, "C")

# %%
# SINGLE FOLD Z NORMALIZED SVM LINEAR WITH PCA = 6
(DTRSF, LTRSF), (DEVSF, LEVSF) = utils.split_db_singleFold(PCA6, L)
minDCF6 = []
print("Start linear SVM on single fold of z normalized features with PCA = 6")
for i in range(len(priors)):
    print("")
    print("Working on application with prior:", priors[i])
    for value in C:
        model.train(DTRSF, LTRSF, option='linear',C=value) 
        temp = metrics.minimum_detection_costs(model.predictAndGetScores(DEVSF), LEVSF, priors[i], 1, 1)
        minDCF6.append(temp)
        print("For C=", value, "the minDCF is", temp)
print("")
print("END")
# Out:
# Start linear SVM on single fold of z normalized features with PCA = 6
#
# Working on application with prior: 0.5
# For C= 0.0001 the minDCF is 0.14596241105170693
# For C= 0.00011244372941080375 the minDCF is 0.14596241105170693
# For C= 0.00012643592283810052 the minDCF is 0.14558955497415285
# For C= 0.00014216926695412638 the minDCF is 0.14040369569888395
# For C= 0.00015986042583922126 the minDCF is 0.13809830761258357
# For C= 0.00017975302466561254 the minDCF is 0.13623402722481326
# For C= 0.0002021210046627367 the minDCF is 0.13548831506970513
# For C= 0.0002272723955653657 the minDCF is 0.13440387264753093
# For C= 0.00025555355749497135 the minDCF is 0.13179388010465248
# For C= 0.00028735395068932865 the minDCF is 0.13179388010465248
# For C= 0.00032311149876436315 the minDCF is 0.13142102402709843
# For C= 0.000363318619365793 the minDCF is 0.12918388756177404
# For C= 0.0004085290052587403 the minDCF is 0.1265056433979196
# For C= 0.00045936524923778616 the minDCF is 0.12355692058797507
# For C= 0.0005165274178602006 the minDCF is 0.12240422654482488
# For C= 0.0005808026920713355 the minDCF is 0.12165851438971675
# For C= 0.0006530762074833568 the minDCF is 0.12240422654482488
# For C= 0.0007343432435889251 the minDCF is 0.12613278732036554
# For C= 0.0008257229297676503 the minDCF is 0.12799706770813585
# For C= 0.0009284736568308978 the minDCF is 0.1327759450953627
# For C= 0.0010440104063375304 the minDCF is 0.1398943363793779
# For C= 0.0011739242363228055 the minDCF is 0.1454555795700148
# For C= 0.0013200041917786596 the minDCF is 0.15521556136958253
# For C= 0.001484261941614863 the minDCF is 0.15589302190371468
# For C= 0.0016689594813769587 the minDCF is 0.1595874568687673
# For C= 0.001876640283215461 the minDCF is 0.16521442384256627
# For C= 0.002110164322072934 the minDCF is 0.16524854965305424
# For C= 0.0023727474604350114 the minDCF is 0.16633299207522845
# For C= 0.002668005734013265 the minDCF is 0.1709778940583172
# For C= 0.0030000051482186037 the minDCF is 0.15924872660170125
#
# Working on application with prior: 0.9
# For C= 0.0001 the minDCF is 0.6457437530808025
# For C= 0.00011244372941080375 the minDCF is 0.6517094503216675
# For C= 0.00012643592283810052 the minDCF is 0.6561837232523161
# For C= 0.00014216926695412638 the minDCF is 0.6461166091583564
# For C= 0.00015986042583922126 the minDCF is 0.6498451699338971
# For C= 0.00017975302466561254 the minDCF is 0.6656808099192357
# For C= 0.0002021210046627367 the minDCF is 0.661030852260519
# For C= 0.0002272723955653657 the minDCF is 0.6563594079803842
# For C= 0.00025555355749497135 the minDCF is 0.6541222715150597
# For C= 0.00028735395068932865 the minDCF is 0.6537494154375058
# For C= 0.00032311149876436315 the minDCF is 0.6526308472048435
# For C= 0.000363318619365793 the minDCF is 0.6539251001655736
# For C= 0.0004085290052587403 the minDCF is 0.650635119250749
# For C= 0.00045936524923778616 the minDCF is 0.64429656593233
# For C= 0.0005165274178602006 the minDCF is 0.638703724769019
# For C= 0.0005808026920713355 the minDCF is 0.633110883605708
# For C= 0.0006530762074833568 the minDCF is 0.6211794891239779
# For C= 0.0007343432435889251 the minDCF is 0.6282637545975052
# For C= 0.0008257229297676503 the minDCF is 0.6297551789077215
# For C= 0.0009284736568308978 the minDCF is 0.6089182118075305
# For C= 0.0010440104063375304 the minDCF is 0.6046853473881115
# For C= 0.0011739242363228055 the minDCF is 0.6004967201304365
# For C= 0.0013200041917786596 the minDCF is 0.5716111174307058
# For C= 0.001484261941614863 the minDCF is 0.561544003336746
# For C= 0.0016689594813769587 the minDCF is 0.5485597644055158
# For C= 0.001876640283215461 the minDCF is 0.5663911323449489
# For C= 0.002110164322072934 the minDCF is 0.5419140787927047
# For C= 0.0023727474604350114 the minDCF is 0.5549640415070969
# For C= 0.002668005734013265 the minDCF is 0.5385583740947182
# For C= 0.0030000051482186037 the minDCF is 0.5370012260013398
#
# Working on application with prior: 0.1
# For C= 0.0001 the minDCF is 0.2907064042771016
# For C= 0.00011244372941080375 the minDCF is 0.2907064042771016
# For C= 0.00012643592283810052 the minDCF is 0.2840632465021044
# For C= 0.00014216926695412638 the minDCF is 0.2772153338641793
# For C= 0.00015986042583922126 the minDCF is 0.27050392446820615
# For C= 0.00017975302466561254 the minDCF is 0.2736890001137527
# For C= 0.0002021210046627367 the minDCF is 0.2736548743032647
# For C= 0.0002272723955653657 the minDCF is 0.26351950858832895
# For C= 0.00025555355749497135 the minDCF is 0.2601296780798544
# For C= 0.00028735395068932865 the minDCF is 0.2565692185189398
# For C= 0.00032311149876436315 the minDCF is 0.24999431236491865
# For C= 0.000363318619365793 the minDCF is 0.2465703560459561
# For C= 0.0004085290052587403 the minDCF is 0.2499601865544307
# For C= 0.00045936524923778616 the minDCF is 0.2499601865544307
# For C= 0.0005165274178602006 the minDCF is 0.24999431236491865
# For C= 0.0005808026920713355 the minDCF is 0.24331702877943348
# For C= 0.0006530762074833568 the minDCF is 0.2500966897963826
# For C= 0.0007343432435889251 the minDCF is 0.25345239449436924
# For C= 0.0008257229297676503 the minDCF is 0.2601979297008304
# For C= 0.0009284736568308978 the minDCF is 0.2568080991923558
# For C= 0.0010440104063375304 the minDCF is 0.263656011830281
# For C= 0.0011739242363228055 the minDCF is 0.2802639062677738
# For C= 0.0013200041917786596 the minDCF is 0.31436696621544763
# For C= 0.001484261941614863 the minDCF is 0.32152201114776474
# For C= 0.0016689594813769587 the minDCF is 0.32785803662836993
# For C= 0.001876640283215461 the minDCF is 0.3381981572062337
# For C= 0.002110164322072934 the minDCF is 0.3344670685928791
# For C= 0.0023727474604350114 the minDCF is 0.334876578318735
# For C= 0.002668005734013265 the minDCF is 0.34847002616312134
# For C= 0.0030000051482186037 the minDCF is 0.33789102491184164
#
# END

# %%
utils.plotDCF(C, minDCF6, "C")

# %%
minDCF3fold = []
print("Start linear SVM with 3-fold on z normalized features")

for i in range(len(priors)):
    print("")
    print("Working on application with prior:", priors[i])
    for value in C:
        temp = utils.KfoldSVM(ZD, L, model, option='linear', C=value, prior=priors[i])
        minDCF3fold.append(temp)
        print("For C=", value, "the minDCF is", temp)
print("")
print("END")
# Out:
# Start linear SVM with 3-fold on z normalized features
#
# Working on application with prior: 0.5
# For C= 0.0001 the minDCF is 0.177526917310449
# For C= 0.00011244372941080375 the minDCF is 0.17748004123291897
# For C= 0.00012643592283810052 the minDCF is 0.17774266746215772
# For C= 0.00014216926695412638 the minDCF is 0.1773721661570646
# For C= 0.00015986042583922126 the minDCF is 0.1754595620963042
# For C= 0.00017975302466561254 the minDCF is 0.1730080333877867
# For C= 0.0002021210046627367 the minDCF is 0.1733630595775414
# For C= 0.0002272723955653657 the minDCF is 0.17063388025596143
# For C= 0.00025555355749497135 the minDCF is 0.16960110411191842
# For C= 0.00028735395068932865 the minDCF is 0.16761202593749525
# For C= 0.00032311149876436315 the minDCF is 0.16526837230483213
# For C= 0.000363318619365793 the minDCF is 0.16440492096648254
# For C= 0.0004085290052587403 the minDCF is 0.1616757416449026
# For C= 0.00045936524923778616 the minDCF is 0.15982548877701064
# For C= 0.0005165274178602006 the minDCF is 0.1595168879332713
# For C= 0.0005808026920713355 the minDCF is 0.15800663687131028
# For C= 0.0006530762074833568 the minDCF is 0.1550462322826832
# For C= 0.0007343432435889251 the minDCF is 0.15475310655428226
# For C= 0.0008257229297676503 the minDCF is 0.15219370276991043
# For C= 0.0009284736568308978 the minDCF is 0.15399753029178706
# For C= 0.0010440104063375304 the minDCF is 0.15410540536764142
# For C= 0.0011739242363228055 the minDCF is 0.15675720911252916
# For C= 0.0013200041917786596 the minDCF is 0.15954828889546288
# For C= 0.001484261941614863 the minDCF is 0.16582322279944237
# For C= 0.0016689594813769587 the minDCF is 0.16627064894971294
# For C= 0.001876640283215461 the minDCF is 0.17263888427723773
# For C= 0.002110164322072934 the minDCF is 0.17751144219511056
# For C= 0.0023727474604350114 the minDCF is 0.18087194612496352
# For C= 0.002668005734013265 the minDCF is 0.18025609663202896
# For C= 0.0030000051482186037 the minDCF is 0.17202258405278847
#
# Working on application with prior: 0.9
# For C= 0.0001 the minDCF is 0.6862923681989685
# For C= 0.00011244372941080375 the minDCF is 0.6872791697285109
# For C= 0.00012643592283810052 the minDCF is 0.6853970651669127
# For C= 0.00014216926695412638 the minDCF is 0.6813583605512568
# For C= 0.00015986042583922126 the minDCF is 0.679722956372044
# For C= 0.00017975302466561254 the minDCF is 0.6786446563450153
# For C= 0.0002021210046627367 the minDCF is 0.6790147069185936
# For C= 0.0002272723955653657 the minDCF is 0.6706268939174835
# For C= 0.00025555355749497135 the minDCF is 0.6668030379905067
# For C= 0.00028735395068932865 the minDCF is 0.6645827345490364
# For C= 0.00032311149876436315 the minDCF is 0.6670497383728924
# For C= 0.000363318619365793 the minDCF is 0.6744507498444602
# For C= 0.0004085290052587403 the minDCF is 0.6735713726592574
# For C= 0.00045936524923778616 the minDCF is 0.6755449757183422
# For C= 0.0005165274178602006 the minDCF is 0.6802322829836683
# For C= 0.0005808026920713355 the minDCF is 0.6726004969765682
# For C= 0.0006530762074833568 the minDCF is 0.6690392672788302
# For C= 0.0007343432435889251 the minDCF is 0.6522795671234631
# For C= 0.0008257229297676503 the minDCF is 0.650568590293617
# For C= 0.0009284736568308978 the minDCF is 0.6530674458111794
# For C= 0.0010440104063375304 the minDCF is 0.6488735393106242
# For C= 0.0011739242363228055 the minDCF is 0.6440669384377374
# For C= 0.0013200041917786596 the minDCF is 0.6373860456828411
# For C= 0.001484261941614863 the minDCF is 0.6162653678787989
# For C= 0.0016689594813769587 the minDCF is 0.605748749933705
# For C= 0.001876640283215461 the minDCF is 0.5987496407294218
# For C= 0.002110164322072934 the minDCF is 0.6058721001248978
# For C= 0.0023727474604350114 the minDCF is 0.5970227380527228
# For C= 0.002668005734013265 the minDCF is 0.6130741887546394
# For C= 0.0030000051482186037 the minDCF is 0.6413132693705249
#
# Working on application with prior: 0.1
# For C= 0.0001 the minDCF is 0.3309523190662285
# For C= 0.00011244372941080375 the minDCF is 0.333819872962825
# For C= 0.00012643592283810052 the minDCF is 0.33446712341795115
# For C= 0.00014216926695412638 the minDCF is 0.32811616613182365
# For C= 0.00015986042583922126 the minDCF is 0.3208844794659492
# For C= 0.00017975302466561254 the minDCF is 0.31336056853470334
# For C= 0.0002021210046627367 the minDCF is 0.3134998445727494
# For C= 0.0002272723955653657 the minDCF is 0.30881208657590836
# For C= 0.00025555355749497135 the minDCF is 0.30551303237589444
# For C= 0.00028735395068932865 the minDCF is 0.2966318186100131
# For C= 0.00032311149876436315 the minDCF is 0.29398001486512537
# For C= 0.000363318619365793 the minDCF is 0.2881056310338864
# For C= 0.0004085290052587403 the minDCF is 0.28445155064411787
# For C= 0.00045936524923778616 the minDCF is 0.2815839967475214
# For C= 0.0005165274178602006 the minDCF is 0.27779064031970685
# For C= 0.0005808026920713355 the minDCF is 0.27603323814384556
# For C= 0.0006530762074833568 the minDCF is 0.2739972838918923
# For C= 0.0007343432435889251 the minDCF is 0.27402868485408394
# For C= 0.0008257229297676503 the minDCF is 0.27524671165067344
# For C= 0.0009284736568308978 the minDCF is 0.27786711443336964
# For C= 0.0010440104063375304 the minDCF is 0.28176834593703853
# For C= 0.0011739242363228055 the minDCF is 0.28728770357852274
# For C= 0.0013200041917786596 the minDCF is 0.29852849682392035
# For C= 0.001484261941614863 the minDCF is 0.3040929276168758
# For C= 0.0016689594813769587 the minDCF is 0.30190402513759707
# For C= 0.001876640283215461 the minDCF is 0.3080255600827363
# For C= 0.002110164322072934 the minDCF is 0.3142549701037298
# For C= 0.0023727474604350114 the minDCF is 0.33138381936964595
# For C= 0.002668005734013265 the minDCF is 0.3602791650709519
# For C= 0.0030000051482186037 the minDCF is 0.42258693747016723
#
# END

# %%
utils.plotDCF(C, minDCF3fold, "C")

# %%
minDCF3fold7 = []
print("Start linear SVM with 3-fold on z normalized features with PCA = 7")
for i in range(len(priors)):
    print("")
    print("Working on application with prior:", priors[i])
    for value in C:
        temp = utils.KfoldSVM(PCA7, L, model, option='linear', C=value, prior=priors[i])
        minDCF3fold7.append(temp)
        print("For C=", value, "the minDCF is", temp)
print("")
print("END")
# Out:
# Start linear SVM with 3-fold on z normalized features with PCA = 7
#
# Working on application with prior: 0.5
# For C= 0.0001 the minDCF is 0.1771568667368706
# For C= 0.00011244372941080375 the minDCF is 0.17748004123291897
# For C= 0.00012643592283810052 the minDCF is 0.17761931727096492
# For C= 0.00014216926695412638 the minDCF is 0.1773726168885793
# For C= 0.00015986042583922126 the minDCF is 0.1752128617139186
# For C= 0.00017975302466561254 the minDCF is 0.1730080333877867
# For C= 0.0002021210046627367 the minDCF is 0.173255184501687
# For C= 0.0002272723955653657 the minDCF is 0.1707572304471542
# For C= 0.00025555355749497135 the minDCF is 0.16972445430311123
# For C= 0.00028735395068932865 the minDCF is 0.16761202593749525
# For C= 0.00032311149876436315 the minDCF is 0.1653917224960249
# For C= 0.000363318619365793 the minDCF is 0.16452827115767535
# For C= 0.0004085290052587403 the minDCF is 0.1616757416449026
# For C= 0.00045936524923778616 the minDCF is 0.16019553935058903
# For C= 0.0005165274178602006 the minDCF is 0.15942448797275538
# For C= 0.0005808026920713355 the minDCF is 0.15800663687131028
# For C= 0.0006530762074833568 the minDCF is 0.15515410735853755
# For C= 0.0007343432435889251 the minDCF is 0.15438305598070387
# For C= 0.0008257229297676503 the minDCF is 0.15231705296110323
# For C= 0.0009284736568308978 the minDCF is 0.15449093105655823
# For C= 0.0010440104063375304 the minDCF is 0.1548455065147982
# For C= 0.0011739242363228055 the minDCF is 0.15644905900030454
# For C= 0.0013200041917786596 the minDCF is 0.15845361229006616
# For C= 0.001484261941614863 the minDCF is 0.16486782223209157
# For C= 0.0016689594813769587 the minDCF is 0.16707265055822346
# For C= 0.001876640283215461 the minDCF is 0.17421148653206722
# For C= 0.002110164322072934 the minDCF is 0.17550688890534893
# For C= 0.0023727474604350114 the minDCF is 0.1792843194863103
# For C= 0.002668005734013265 the minDCF is 0.17797389272920489
# For C= 0.0030000051482186037 the minDCF is 0.17254693504823654
#
# Working on application with prior: 0.9
# For C= 0.0001 the minDCF is 0.6862923681989685
# For C= 0.00011244372941080375 the minDCF is 0.6872791697285109
# For C= 0.00012643592283810052 the minDCF is 0.6846410381729028
# For C= 0.00014216926695412638 the minDCF is 0.6809883099776782
# For C= 0.00015986042583922126 the minDCF is 0.6786446563450153
# For C= 0.00017975302466561254 the minDCF is 0.6783979559626296
# For C= 0.0002021210046627367 the minDCF is 0.6792614073009793
# For C= 0.0002272723955653657 the minDCF is 0.670873594299869
# For C= 0.00025555355749497135 the minDCF is 0.666679687799314
# For C= 0.00028735395068932865 the minDCF is 0.6644593843578437
# For C= 0.00032311149876436315 the minDCF is 0.6674197889464707
# For C= 0.000363318619365793 the minDCF is 0.6746815243799926
# For C= 0.0004085290052587403 the minDCF is 0.6734480224680646
# For C= 0.00045936524923778616 the minDCF is 0.6751749251447637
# For C= 0.0005165274178602006 the minDCF is 0.6786287304981621
# For C= 0.0005808026920713355 the minDCF is 0.6734639483149178
# For C= 0.0006530762074833568 the minDCF is 0.6673123646021311
# For C= 0.0007343432435889251 the minDCF is 0.6525262675058486
# For C= 0.0008257229297676503 the minDCF is 0.6515553918231596
# For C= 0.0009284736568308978 the minDCF is 0.6578621774208453
# For C= 0.0010440104063375304 the minDCF is 0.6492435898842026
# For C= 0.0011739242363228055 the minDCF is 0.6446836893937015
# For C= 0.0013200041917786596 the minDCF is 0.6313896638549535
# For C= 0.001484261941614863 the minDCF is 0.6181474724403971
# For C= 0.0016689594813769587 the minDCF is 0.6099426564342599
# For C= 0.001876640283215461 the minDCF is 0.598148815620311
# For C= 0.002110164322072934 the minDCF is 0.6237578778478532
# For C= 0.0023727474604350114 the minDCF is 0.5766858823527645
# For C= 0.002668005734013265 the minDCF is 0.6066918305063203
# For C= 0.0030000051482186037 the minDCF is 0.6372786213385013
#
# Working on application with prior: 0.1
# For C= 0.0001 the minDCF is 0.3309523190662285
# For C= 0.00011244372941080375 the minDCF is 0.333819872962825
# For C= 0.00012643592283810052 the minDCF is 0.33446712341795115
# For C= 0.00014216926695412638 the minDCF is 0.32811616613182365
# For C= 0.00015986042583922126 the minDCF is 0.3202686299730147
# For C= 0.00017975302466561254 the minDCF is 0.31447072025543854
# For C= 0.0002021210046627367 the minDCF is 0.3134998445727494
# For C= 0.0002272723955653657 the minDCF is 0.30881208657590836
# For C= 0.00025555355749497135 the minDCF is 0.30551303237589444
# For C= 0.00028735395068932865 the minDCF is 0.2966318186100131
# For C= 0.00032311149876436315 the minDCF is 0.29398001486512537
# For C= 0.000363318619365793 the minDCF is 0.2879977559580321
# For C= 0.0004085290052587403 the minDCF is 0.2830177736958196
# For C= 0.00045936524923778616 the minDCF is 0.28101322040605803
# For C= 0.0005165274178602006 the minDCF is 0.27868504188873333
# For C= 0.0005808026920713355 the minDCF is 0.2749230864231104
# For C= 0.0006530762074833568 the minDCF is 0.27499956053677316
# For C= 0.0007343432435889251 the minDCF is 0.27299500724701153
# For C= 0.0008257229297676503 the minDCF is 0.2762489882955543
# For C= 0.0009284736568308978 the minDCF is 0.27919301630581356
# For C= 0.0010440104063375304 the minDCF is 0.2815211948231382
# For C= 0.0011739242363228055 the minDCF is 0.2873955786543771
# For C= 0.0013200041917786596 the minDCF is 0.30010154981026455
# For C= 0.001484261941614863 the minDCF is 0.30709975755151825
# For C= 0.0016689594813769587 the minDCF is 0.3042636046171133
# For C= 0.001876640283215461 the minDCF is 0.31164823951031323
# For C= 0.002110164322072934 the minDCF is 0.3196978536315513
# For C= 0.0023727474604350114 the minDCF is 0.3220711053003472
# For C= 0.002668005734013265 the minDCF is 0.3520452017601967
# For C= 0.0030000051482186037 the minDCF is 0.4355674041185141
#
# END

# %%
utils.plotDCF(C, minDCF3fold7, "C")

# %%
minDCF3fold6 = []
print("Start linear SVM with 3-fold on z normalized features with PCA = 6")
for i in range(len(priors)):
    print("")
    print("Working on application with prior:", priors[i])
    for value in C:
        temp = utils.KfoldSVM(PCA6, L, model, option='linear', C=value, prior=priors[i])
        minDCF3fold6.append(temp)
        print("For C=", value, "the minDCF is", temp)
print("")
print("END")
# Out:
# Start linear SVM with 3-fold on z normalized features with PCA = 6
#
# Working on application with prior: 0.5
# For C= 0.0001 the minDCF is 0.17883734406755444
# For C= 0.00011244372941080375 the minDCF is 0.1788214182207013
# For C= 0.00012643592283810052 the minDCF is 0.17891426891273193
# For C= 0.00014216926695412638 the minDCF is 0.17757244119343488
# For C= 0.00015986042583922126 the minDCF is 0.175845087785221
# For C= 0.00017975302466561254 the minDCF is 0.1730080333877867
# For C= 0.0002021210046627367 the minDCF is 0.17408768560935972
# For C= 0.0002272723955653657 the minDCF is 0.17186738216788938
# For C= 0.00025555355749497135 the minDCF is 0.1705414802954455
# For C= 0.00028735395068932865 the minDCF is 0.16886100296476164
# For C= 0.00032311149876436315 the minDCF is 0.1661318236431817
# For C= 0.000363318619365793 the minDCF is 0.1655150726872177
# For C= 0.0004085290052587403 the minDCF is 0.16292471867216898
# For C= 0.00045936524923778616 the minDCF is 0.16190696691194975
# For C= 0.0005165274178602006 the minDCF is 0.15981001366167222
# For C= 0.0005808026920713355 the minDCF is 0.16098161511224643
# For C= 0.0006530762074833568 the minDCF is 0.15785233644944063
# For C= 0.0007343432435889251 the minDCF is 0.15762111118239347
# For C= 0.0008257229297676503 the minDCF is 0.15492288209149038
# For C= 0.0009284736568308978 the minDCF is 0.15439853109604232
# For C= 0.0010440104063375304 the minDCF is 0.1596871142019941
# For C= 0.0011739242363228055 the minDCF is 0.16391152020171135
# For C= 0.0013200041917786596 the minDCF is 0.1673348260559475
# For C= 0.001484261941614863 the minDCF is 0.17155968278717945
# For C= 0.0016689594813769587 the minDCF is 0.18280002530106237
# For C= 0.001876640283215461 the minDCF is 0.18972266039168267
# For C= 0.002110164322072934 the minDCF is 0.19188106337179928
# For C= 0.0023727474604350114 the minDCF is 0.1980180734322769
# For C= 0.002668005734013265 the minDCF is 0.2024737046990413
# For C= 0.0030000051482186037 the minDCF is 0.20882601417971297
#
# Working on application with prior: 0.9
# For C= 0.0001 the minDCF is 0.6855204153581055
# For C= 0.00011244372941080375 the minDCF is 0.6824366605782856
# For C= 0.00012643592283810052 the minDCF is 0.6803397073280081
# For C= 0.00014216926695412638 the minDCF is 0.6821899601959001
# For C= 0.00015986042583922126 the minDCF is 0.6813265088575504
# For C= 0.00017975302466561254 the minDCF is 0.6796314578745576
# For C= 0.0002021210046627367 the minDCF is 0.6818199096223215
# For C= 0.0002272723955653657 the minDCF is 0.6738339988884962
# For C= 0.00025555355749497135 the minDCF is 0.6684065904760131
# For C= 0.00028735395068932865 the minDCF is 0.6697634425791339
# For C= 0.00032311149876436315 the minDCF is 0.6669263881816996
# For C= 0.000363318619365793 the minDCF is 0.6703801935350978
# For C= 0.0004085290052587403 the minDCF is 0.6769018278214629
# For C= 0.00045936524923778616 the minDCF is 0.6796314578745576
# For C= 0.0005165274178602006 the minDCF is 0.6796473837214106
# For C= 0.0005808026920713355 the minDCF is 0.678429807656336
# For C= 0.0006530762074833568 the minDCF is 0.6743114738064142
# For C= 0.0007343432435889251 the minDCF is 0.664013761133632
# For C= 0.0008257229297676503 the minDCF is 0.659712430288737
# For C= 0.0009284736568308978 the minDCF is 0.6684424987533517
# For C= 0.0010440104063375304 the minDCF is 0.6586381868453407
# For C= 0.0011739242363228055 the minDCF is 0.6566168062456965
# For C= 0.0013200041917786596 the minDCF is 0.6391766517469528
# For C= 0.001484261941614863 the minDCF is 0.6277687873534353
# For C= 0.0016689594813769587 the minDCF is 0.6067992548506599
# For C= 0.001876640283215461 the minDCF is 0.6059358035123104
# For C= 0.002110164322072934 the minDCF is 0.6054264769006861
# For C= 0.0023727474604350114 the minDCF is 0.6115780606134726
# For C= 0.002668005734013265 the minDCF is 0.6277210098128758
# For C= 0.0030000051482186037 the minDCF is 0.6587534238692687
#
# Working on application with prior: 0.1
# For C= 0.0001 the minDCF is 0.33428277422843405
# For C= 0.00011244372941080375 the minDCF is 0.3381526047699113
# For C= 0.00012643592283810052 the minDCF is 0.335469400062832
# For C= 0.00014216926695412638 the minDCF is 0.32905564085232125
# For C= 0.00015986042583922126 the minDCF is 0.32066872931424056
# For C= 0.00017975302466561254 the minDCF is 0.3190192022142336
# For C= 0.0002021210046627367 the minDCF is 0.31550439786251094
# For C= 0.0002272723955653657 the minDCF is 0.3120346666622595
# For C= 0.00025555355749497135 the minDCF is 0.3063760329827293
# For C= 0.00028735395068932865 the minDCF is 0.3002858989997817
# For C= 0.00032311149876436315 the minDCF is 0.295845292116841
# For C= 0.000363318619365793 the minDCF is 0.29032593447535676
# For C= 0.0004085290052587403 the minDCF is 0.2909731849304829
# For C= 0.00045936524923778616 the minDCF is 0.2846673007958266
# For C= 0.0005165274178602006 the minDCF is 0.28155259578532976
# For C= 0.0005808026920713355 the minDCF is 0.27779064031970685
# For C= 0.0006530762074833568 the minDCF is 0.2787929169645877
# For C= 0.0007343432435889251 the minDCF is 0.28022669391288596
# For C= 0.0008257229297676503 the minDCF is 0.28477517587168094
# For C= 0.0009284736568308978 the minDCF is 0.289323657830476
# For C= 0.0010440104063375304 the minDCF is 0.28717982850266843
# For C= 0.0011739242363228055 the minDCF is 0.29989947184783544
# For C= 0.0013200041917786596 the minDCF is 0.3092121859171342
# For C= 0.001484261941614863 the minDCF is 0.3295636152694015
# For C= 0.0016689594813769587 the minDCF is 0.33278619535575266
# For C= 0.001876640283215461 the minDCF is 0.3349300246835602
# For C= 0.002110164322072934 the minDCF is 0.3480811683321447
# For C= 0.0023727474604350114 the minDCF is 0.36333106815706545
# For C= 0.002668005734013265 the minDCF is 0.4147216725384463
# For C= 0.0030000051482186037 the minDCF is 0.6199168941233174
#
# END

# %%
utils.plotDCF(C, minDCF3fold6, "C")
